# %% [markdown]
# <a href="https://colab.research.google.com/github/osamamalik234/DS-A/blob/main/Lab_15_20SW032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("/content/book-recommendation-dataset"))

# Any results you write to the current directory are saved as output.
# Out:
# ['recsys_taxonomy2.png', 'Users.csv', 'Ratings.csv', 'Books.csv']

# %%
# import movie data set and look at columns
book = pd.read_csv("/content/book-recommendation-dataset/Books.csv")
book.columns
# Out:
# <ipython-input-3-d3794bd3e037>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv("/content/book-recommendation-dataset/Books.csv")
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
# what we need is that movie id and title
book = book.loc[:,["ISBN","Book-Title"]]
book.head(10)
# Out:
#          ISBN                                         Book-Title
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories

# %%
# import rating data and look at columsn
rating = pd.read_csv("/content/book-recommendation-dataset/Ratings.csv")
rating.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
# what we need is that user id, movie id and rating
rating = rating.loc[:,["User-ID","ISBN","Book-Rating"]]
rating.head(10)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
# 5   276733  2080674722            0
# 6   276736  3257224281            8
# 7   276737  0600570967            6
# 8   276744  038550120X            7
# 9   276745   342310538           10

# %%
# then merge book and rating data
data = pd.merge(book,rating)

# %%
# now lets look at our data
data.head(10)
# Out:
#          ISBN           Book-Title  User-ID  Book-Rating
# 0  0195153448  Classical Mythology        2            0
# 1  0002005018         Clara Callan        8            5
# 2  0002005018         Clara Callan    11400            0
# 3  0002005018         Clara Callan    11676            8
# 4  0002005018         Clara Callan    41385            0
# 5  0002005018         Clara Callan    67544            8
# 6  0002005018         Clara Callan    85526            0
# 7  0002005018         Clara Callan    96054            0
# 8  0002005018         Clara Callan   116866            9
# 9  0002005018         Clara Callan   123629            9

# %%
data.shape
# Out:
# (1031136, 4)

# %%
data = data.iloc[:1000000,:]

# %%
# lets make a pivot table in order to make rows are users and columns are movies. And values are rating
pivot_table = data.pivot_table(index = ["User-ID"],columns = ["Book-Title"],values = "Book-Rating")
pivot_table.head(10)
# Out:
# <ipython-input-11-a476f79d6550>:2: PerformanceWarning: The following operation may generate 19719000756 cells in the resulting pandas object.
#   pivot_table = data.pivot_table(index = ["User-ID"],columns = ["Book-Title"],values = "Book-Rating")

# %%
book_readed = pivot_table["The Pillars of the Earth"]
similarity_with_other_books = pivot_table.corrwith(book_readed)
similarity_with_other_books = similarity_with_other_books.sort_values(ascending=False)
similarity_with_other_books.head()
